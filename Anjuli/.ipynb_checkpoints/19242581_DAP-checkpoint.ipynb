# %% [markdown]
# <h1> DAP Semester 1 - 19242581

# %% [markdown]
# <h2> Retrieving Data

# %%
#All Imports collected 
import os

# Data manipulation
import pandas as pd
import numpy as np
from numpy import nan as NA
import random
import csv

# Data Visualization
from matplotlib import pyplot
# %matplotlib inline
import seaborn as sns

# Database imports
import sqlalchemy
import psycopg2
import world_bank_data as wb

# Remove the limit of characters in each
# column cell display
pd.options.display.max_colwidth = None

# %% [markdown]
# <h2> Web Scraping

# %%
wb.get_topics()
# Out:
#                               value  \
# id
# 1   Agriculture & Rural Development
# 2                 Aid Effectiveness
# 3                  Economy & Growth
# 4                         Education
# 5                   Energy & Mining
# 6                       Environment
# 7                  Financial Sector
# 8                            Health
# 9                    Infrastructure
# 10        Social Protection & Labor
# 11                          Poverty
# 12                   Private Sector
# 13                    Public Sector
# 14             Science & Technology
# 15               Social Development
# 16                Urban Development
# 17                           Gender
# 18      Millenium development goals
# 19                   Climate Change
# 20                    External Debt
# 21                            Trade
#
# ...

# %%
#Getting most recent figures for series


f= open('web_scrapped_data.csv','w',newline='',encoding = 'utf-8')
csvwriter= csv.writer(f)
cnt=0

lst_series =['SP.ADO.TFRT','SH.HIV.TOTL','SH.HIV.INCD.TL','SH.DYN.AIDS','SH.HIV.INCD','SP.DYN.SMAM.FE','SP.DYN.SMAM.MA','SP.POP.DPND','SP.POP.DPND.OL','SP.POP.DPND.YG','SH.DYN.AIDS.DH','SH.HIV.ARTC.ZS','SP.DYN.CBRT.IN','SH.XPD.KHEX.GD.ZS','SH.DTH.COMM.ZS','SH.DTH.INJR.ZS','SH.DTH.NCOM.ZS','SH.HIV.0014','SH.HIV.INCD.14','SH.HIV.ORPH','SH.CON.1524.FE.ZS','SH.CON.1524.MA.ZS','SN.ITK.SALT.ZS','SP.DYN.CONU.ZS','SP.DYN.CONM.ZS','SH.XPD.CHEX.GD.ZS','SH.FPL.SATI.ZS','SH.FPL.SATM.ZS','SH.STA.DIAB.ZS','SH.STA.BFED.ZS','SH.XPD.EHEX.CH.ZS']
for x in lst_series:
    ws_1 = wb.get_series(lst_series[cnt], mrv = 1)
    cnt+=1
    csvwriter.writerow(ws_1)

# %% [markdown]
# <h2> Getting the data from csv file :

# %%
# Set the directory of the notebook as the working directory
os.chdir(os.getcwd())

# %%
file_data = pd.read_csv(os.getcwd() + '/World_bank_Nutrition_helath_population_stats.csv')
file_data
# Out:
#       Country_Name  \
# 0      Afghanistan
# 1      Afghanistan
# 2      Afghanistan
# 3      Afghanistan
# 4      Afghanistan
# ...            ...
# 29782     Zimbabwe
# 29783     Zimbabwe
# 29784     Zimbabwe
# 29785          NaN
# 29786          NaN
#
#                                                               Series_Name  \
# 0            Adolescent_fertility_rate_(births_per_1000_women_ages_15-19)
# 1             Adults_(ages_15+)_and_children_(0-14_years)_living_with_HIV
# 2      Adults_(ages_15+)_and_children_(ages_0-14)_newly_infected_with_HIV
# 3                                       Adults_(ages_15+)_living_with_HIV
# 4                             Adults_(ages_15-49)_newly_infected_with_HIV
# ...                                                                   ...
# 29782      Women_who_were_first_married_by_age_18_(%_of_women_ages_20-24)
# 29783            Women's_share_of_population_ages_15+_living_with_HIV_(%)
# ...

# %%
file_data_V1=file_data.melt(id_vars=['Country_Name','Series_Name','Series_Code','Country_Code'])
file_data_V1.rename(columns={'variable': 'Year'}, index={'variable': 'Year'})

#print(file_data_V1['variable'])
year_split= file_data_V1['variable'].str.split("_",n=1, expand=True)
file_data_V1['variable']=year_split[0]
file_data_V1.head()
# Out:
#   Country_Name  \
# 0  Afghanistan
# 1  Afghanistan
# 2  Afghanistan
# 3  Afghanistan
# 4  Afghanistan
#
#                                                           Series_Name  \
# 0        Adolescent_fertility_rate_(births_per_1000_women_ages_15-19)
# 1         Adults_(ages_15+)_and_children_(0-14_years)_living_with_HIV
# 2  Adults_(ages_15+)_and_children_(ages_0-14)_newly_infected_with_HIV
# 3                                   Adults_(ages_15+)_living_with_HIV
# 4                         Adults_(ages_15-49)_newly_infected_with_HIV
#
#       Series_Code Country_Code variable     value
# 0     SP.ADO.TFRT          AFG     2005  138.4284
# 1     SH.HIV.TOTL          AFG     2005      2900
# 2  SH.HIV.INCD.TL          AFG     2005       500
# 3     SH.DYN.AIDS          AFG     2005      2700
# 4     SH.HIV.INCD          AFG     2005       500

# %%
file_data_V1.to_csv(os.getcwd() + '/V1.csv')

del file_data_V1['Series_Code']
file_data_V2 = file_data_V1.copy()
file_data_V1
# Out:
#        Country_Name  \
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
# ...             ...
# 476587     Zimbabwe
# 476588     Zimbabwe
# 476589     Zimbabwe
# 476590          NaN
# 476591          NaN
#
#                                                                Series_Name  \
# 0             Adolescent_fertility_rate_(births_per_1000_women_ages_15-19)
# 1              Adults_(ages_15+)_and_children_(0-14_years)_living_with_HIV
# 2       Adults_(ages_15+)_and_children_(ages_0-14)_newly_infected_with_HIV
# 3                                        Adults_(ages_15+)_living_with_HIV
# 4                              Adults_(ages_15-49)_newly_infected_with_HIV
# ...                                                                    ...
# 476587      Women_who_were_first_married_by_age_18_(%_of_women_ages_20-24)
# 476588            Women's_share_of_population_ages_15+_living_with_HIV_(%)
# ...

# %%
dap_dataset_V1 = pd.pivot_table(file_data_V2, values='value', index=['Country_Name', 'variable','Country_Code'],
                    columns=['Series_Name'], aggfunc=np.sum)

# %%
dap_dataset_V1
# Out:
# Series_Name                        AIDS_estimated_deaths_(UNAIDS_estimates)  \
# Country_Name variable Country_Code
# Afghanistan  2005     AFG                                               200
#              2006     AFG                                               200
#              2007     AFG                                               200
#              2008     AFG                                               200
#              2009     AFG                                               500
# ...                                                                     ...
# Zimbabwe     2016     ZWE                                             23000
#              2017     ZWE                                             23000
#              2018     ZWE                                             22000
#              2019     ZWE                                             20000
#              2020     ZWE                                                ..
#
# ...

# %%
dap_dataset_V1.rename(columns={'variable':'Year'}, inplace=True)

#print(dap_dataset_V1)

# %%
dap_dataset_V1.to_csv(os.getcwd() + '/dap_dataset_V1.csv')

# %%
dap_dataset_V2 = pd.read_csv(os.getcwd() + '/dap_dataset_V1.csv')
dap_dataset_V2
# Out:
#      Country_Name  variable Country_Code  \
# 0     Afghanistan      2005          AFG
# 1     Afghanistan      2006          AFG
# 2     Afghanistan      2007          AFG
# 3     Afghanistan      2008          AFG
# 4     Afghanistan      2009          AFG
# ...           ...       ...          ...
# 4139     Zimbabwe      2016          ZWE
# 4140     Zimbabwe      2017          ZWE
# 4141     Zimbabwe      2018          ZWE
# 4142     Zimbabwe      2019          ZWE
# 4143     Zimbabwe      2020          ZWE
#
#      AIDS_estimated_deaths_(UNAIDS_estimates)  \
# 0                                         200
# 1                                         200
# 2                                         200
# 3                                         200
# 4                                         500
# ...                                       ...
# 4139                                    23000
# 4140                                    23000
# ...

# %% [markdown]
# <h2> Connecting to Database

# %%
db_dataset_V1 = pd.read_csv(os.getcwd() + '/dap_dataset_V1.csv')
db_dataset_V1.head(3)
# Out:
#   Country_Name  variable Country_Code  \
# 0  Afghanistan      2005          AFG
# 1  Afghanistan      2006          AFG
# 2  Afghanistan      2007          AFG
#
#   AIDS_estimated_deaths_(UNAIDS_estimates)  \
# 0                                      200
# 1                                      200
# 2                                      200
#
#   Adolescent_fertility_rate_(births_per_1000_women_ages_15-19)  \
# 0                                                     138.4284
# 1                                                     135.7602
# 2                                                      133.092
#
#   Adults_(ages_15+)_and_children_(0-14_years)_living_with_HIV  \
# 0                                                        2900
# 1                                                        3200
# 2                                                        3500
#
#   Adults_(ages_15+)_and_children_(ages_0-14)_newly_infected_with_HIV  \
# ...

# %%
db_dataset_V1.reset_index(drop=True, inplace=True)
db_dataset_V1.shape
# Out:
# (4144, 118)

# %%
db_dataset_V1.head()
db_dataset_V1.columns = db_dataset_V1.columns.str.replace(r'\%', '')
db_dataset_V1.columns = db_dataset_V1.columns.str.replace(' ', '')
db_dataset_V1.columns = db_dataset_V1.columns.str.replace('\(|\)', '')
db_dataset_V1.columns = db_dataset_V1.columns.str.replace(r'\$', '')
db_dataset_V1.columns = db_dataset_V1.columns.str.replace(r'\-', '')
db_dataset_V1.columns = db_dataset_V1.columns.str.replace(r'\+', '')
db_dataset_V1.columns = db_dataset_V1.columns.str.replace(r'\__', '_')

# %%
db_dataset_V1.columns = db_dataset_V1.columns.str.lower()

# %%
db_dataset_V1.head()
# Out:
#   country_name  variable country_code aids_estimated_deaths_unaids_estimates  \
# 0  Afghanistan      2005          AFG                                    200
# 1  Afghanistan      2006          AFG                                    200
# 2  Afghanistan      2007          AFG                                    200
# 3  Afghanistan      2008          AFG                                    200
# 4  Afghanistan      2009          AFG                                    500
#
#   adolescent_fertility_rate_births_per_1000_women_ages_1519  \
# 0                                                  138.4284
# 1                                                  135.7602
# 2                                                   133.092
# 3                                                   126.633
# 4                                                   120.174
#
#   adults_ages_15_and_children_014_years_living_with_hiv  \
# 0                                                  2900
# ...

# %%
db_dataset_V1.columns
# Out:
# Index(['country_name', 'variable', 'country_code',
#        'aids_estimated_deaths_unaids_estimates',
#        'adolescent_fertility_rate_births_per_1000_women_ages_1519',
#        'adults_ages_15_and_children_014_years_living_with_hiv',
#        'adults_ages_15_and_children_ages_014_newly_infected_with_hiv',
#        'adults_ages_15_living_with_hiv',
#        'adults_ages_1549_newly_infected_with_hiv',
#        'age_at_first_marriage_female',
#        ...
#        'tuberculosis_death_rate_per_100000_people',
#        'unemployment_female_of_female_labor_force',
#        'unemployment_male_of_male_labor_force',
#        'unemployment_total_of_total_labor_force', 'urban_population',
#        'wanted_fertility_rate_births_per_woman',
#        'women's_share_of_population_ages_15_living_with_hiv_',
#        'women_who_were_first_married_by_age_15_of_women_ages_2024',
#        'women_who_were_first_married_by_age_18_of_women_ages_2024',
# ...

# %% [markdown]
# <h2> Open Connection

# %%
# Create the engine and connect to the database
# engine = sqlalchemy.create_engine("postgresql+psycopg2://user:password@host:port/dbname")
try:
    engine = sqlalchemy.create_engine("postgresql+psycopg2://dap:dap@192.168.56.30:5432/postgres")
    dbconn = engine.connect()
except: 
    print("Error: Could not make connection to the Postgres database")
    print(e)

# Check for existing tables in the database
engine.table_names()
# Out:
# ['stack_overflow_survey_2020',
#  'edu_stats1',
#  'clean_stack_overflow_survey_2020']

# %%
# Execute queries using teh connection
# engine.execute("SQL query")
# engine.execute("DROP TABLE world_nutrition_and_health_dap_2020")

# %%
# engine.table_names()

# %%
# Set the table name
table = 'world_nutrition_and_health_dap_2020'

# Write the dataframe to the database as a table
try:
    db_dataset_V1.to_sql(table, dbconn, if_exists = 'fail', index= False)
    #engine.execute("SELECT * FROM world_nutrition_and_health_dap_2020").fetchall()
except ValueError as e:
    print('Table already exists')
except Exception as exc:
    print(exc)
else:
    print(f'Table {table} was created with success.')
finally:
    dbconn.close()
# Out:
# Table world_nutrition_and_health_dap_2020 was created with success.

# %% [markdown]
# <h2> List of columns into databse

# %%
# Create the engine and connect to the database
# engine = sqlalchemy.create_engine("postgresql+psycopg2://user:password@host:port/dbname")
try:
    engine = sqlalchemy.create_engine("postgresql+psycopg2://dap:dap@192.168.56.30:5432/postgres")
    dbconn = engine.connect()
except: 
    print("Error: Could not make connection to the Postgres database")
    print(e)

# Check for existing tables in the database
engine.table_names()
# Out:
# ['stack_overflow_survey_2020',
#  'edu_stats1',
#  'clean_stack_overflow_survey_2020',
#  'world_nutrition_and_health_dap_2020']

# %%
db_dataset_V2 = pd.read_sql("SELECT world_nutrition_and_health_dap_2020.country_name,world_nutrition_and_health_dap_2020.variable as year,world_nutrition_and_health_dap_2020.country_code,world_nutrition_and_health_dap_2020.literacy_rate_adult_female_of_females_ages_15_and_above,world_nutrition_and_health_dap_2020.literacy_rate_adult_male_of_males_ages_15_and_above,world_nutrition_and_health_dap_2020.literacy_rate_adult_total_of_people_ages_15_and_above,world_nutrition_and_health_dap_2020.literacy_rate_youth_male_of_males_ages_1524,world_nutrition_and_health_dap_2020.literacy_rate_youth_total_of_people_ages_1524,world_nutrition_and_health_dap_2020.number_of_deaths_ages_1014_years,world_nutrition_and_health_dap_2020.number_of_deaths_ages_1519_years,world_nutrition_and_health_dap_2020.number_of_deaths_ages_2024_years,world_nutrition_and_health_dap_2020.number_of_deaths_ages_59_years,world_nutrition_and_health_dap_2020.number_of_infant_deaths,world_nutrition_and_health_dap_2020.number_of_infant_deaths_female,world_nutrition_and_health_dap_2020.number_of_infant_deaths_male,world_nutrition_and_health_dap_2020.number_of_maternal_deaths,world_nutrition_and_health_dap_2020.number_of_neonatal_deaths,world_nutrition_and_health_dap_2020.number_of_stillbirths,world_nutrition_and_health_dap_2020.total_alcohol_consumption_per_capita_female_liters_of_pure_alcohol_projected_estimates_female_15_years_of_age,world_nutrition_and_health_dap_2020.total_alcohol_consumption_per_capita_male_liters_of_pure_alcohol_projected_estimates_male_15_years_of_age,world_nutrition_and_health_dap_2020.tuberculosis_death_rate_per_100000_people,world_nutrition_and_health_dap_2020.unemployment_female_of_female_labor_force,world_nutrition_and_health_dap_2020.unemployment_male_of_male_labor_force,world_nutrition_and_health_dap_2020.unemployment_total_of_total_labor_force,world_nutrition_and_health_dap_2020.capital_health_expenditure_of_gdp,world_nutrition_and_health_dap_2020.cause_of_death_by_communicable_diseases_and_maternal_prenatal_and_nutrition_conditions_of_total,world_nutrition_and_health_dap_2020.cause_of_death_by_injury_of_total,world_nutrition_and_health_dap_2020.cause_of_death_by_noncommunicable_diseases_of_total,world_nutrition_and_health_dap_2020.children_014_living_with_hiv,world_nutrition_and_health_dap_2020.children_ages_014_newly_infected_with_hiv,world_nutrition_and_health_dap_2020.condom_use_population_ages_1524_female_of_females_ages_1524,world_nutrition_and_health_dap_2020.condom_use_population_ages_1524_male_of_males_ages_1524,world_nutrition_and_health_dap_2020.consumption_of_iodized_salt_of_households,world_nutrition_and_health_dap_2020.contraceptive_prevalence_any_methods_of_women_ages_1549,world_nutrition_and_health_dap_2020.contraceptive_prevalence_modern_methods_of_women_ages_1549,world_nutrition_and_health_dap_2020.current_health_expenditure_of_gdp,world_nutrition_and_health_dap_2020.demand_for_family_planning_satisfied_by_any_methods_of_married_women_with_demand_for_family_planning,world_nutrition_and_health_dap_2020.demand_for_family_planning_satisfied_by_modern_methods_of_married_women_with_demand_for_family_planning,world_nutrition_and_health_dap_2020.diabetes_prevalence_of_population_ages_20_to_79,world_nutrition_and_health_dap_2020.exclusive_breastfeeding_of_children_under_6_months,world_nutrition_and_health_dap_2020.external_health_expenditure_of_current_health_expenditure,world_nutrition_and_health_dap_2020.external_health_expenditure_channeled_through_government_of_external_health_expenditure,world_nutrition_and_health_dap_2020.external_health_expenditure_per_capita_ppp_current_international_ FROM world_nutrition_and_health_dap_2020", dbconn)

dbconn.close()

# %%
db_dataset_V2
# Out:
#      country_name  year country_code  \
# 0     Afghanistan  2005          AFG
# 1     Afghanistan  2006          AFG
# 2     Afghanistan  2007          AFG
# 3     Afghanistan  2008          AFG
# 4     Afghanistan  2009          AFG
# ...           ...   ...          ...
# 4139     Zimbabwe  2016          ZWE
# 4140     Zimbabwe  2017          ZWE
# 4141     Zimbabwe  2018          ZWE
# 4142     Zimbabwe  2019          ZWE
# 4143     Zimbabwe  2020          ZWE
#
#      literacy_rate_adult_female_of_females_ages_15_and_above  \
# 0                                                         ..
# 1                                                         ..
# 2                                                         ..
# 3                                                         ..
# 4                                                         ..
# ...                                                      ...
# 4139                                                      ..
# ...

# %%
 db_dataset_V2.to_csv(os.getcwd() + '/db_dataset_V2.csv')

# %% [markdown]
# <h2> Transformations in dataset </h2>
#
#   1. We will check for null data in our table
#   2. We have data - '..' in columns, which we will replace as 0, because all the columns selected to perform analysis is numeric , so if the data is null or missing , we can replace it with 0.

# %% [markdown]
#  ###### Updating All records where data = ".." to 0

# %%
patrn = '..'

engine.execute(f"Update world_nutrition_and_health_dap_2020 set literacy_rate_adult_female_of_females_ages_15_and_above = 0 where trim(world_nutrition_and_health_dap_2020.literacy_rate_adult_female_of_females_ages_15_and_above)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set literacy_rate_adult_male_of_males_ages_15_and_above = 0 where trim(world_nutrition_and_health_dap_2020.literacy_rate_adult_male_of_males_ages_15_and_above)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set literacy_rate_adult_total_of_people_ages_15_and_above = 0 where trim(world_nutrition_and_health_dap_2020.literacy_rate_adult_total_of_people_ages_15_and_above)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set literacy_rate_youth_male_of_males_ages_1524 = 0 where trim(world_nutrition_and_health_dap_2020.literacy_rate_youth_male_of_males_ages_1524)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set literacy_rate_youth_total_of_people_ages_1524 = 0 where trim(world_nutrition_and_health_dap_2020.literacy_rate_youth_total_of_people_ages_1524)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set number_of_deaths_ages_1014_years = 0 where trim(world_nutrition_and_health_dap_2020.number_of_deaths_ages_1014_years)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set number_of_deaths_ages_1519_years = 0 where trim(world_nutrition_and_health_dap_2020.number_of_deaths_ages_1519_years)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set number_of_deaths_ages_2024_years = 0 where trim(world_nutrition_and_health_dap_2020.number_of_deaths_ages_2024_years)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set number_of_deaths_ages_59_years = 0 where trim(world_nutrition_and_health_dap_2020.number_of_deaths_ages_59_years)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set number_of_infant_deaths = 0 where trim(world_nutrition_and_health_dap_2020.number_of_infant_deaths)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set number_of_infant_deaths_female = 0 where trim(world_nutrition_and_health_dap_2020.number_of_infant_deaths_female)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set number_of_infant_deaths_male = 0 where trim(world_nutrition_and_health_dap_2020.number_of_infant_deaths_male)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set number_of_maternal_deaths = 0 where trim(world_nutrition_and_health_dap_2020.number_of_maternal_deaths)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set number_of_neonatal_deaths = 0 where trim(world_nutrition_and_health_dap_2020.number_of_neonatal_deaths)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set number_of_stillbirths = 0 where trim(world_nutrition_and_health_dap_2020.number_of_stillbirths)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set total_alcohol_consumption_per_capita_female_liters_of_pure_alcohol_projected_estimates_female_15_years_of_age = 0 where trim(world_nutrition_and_health_dap_2020.total_alcohol_consumption_per_capita_female_liters_of_pure_alcohol_projected_estimates_female_15_years_of_age)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set total_alcohol_consumption_per_capita_male_liters_of_pure_alcohol_projected_estimates_male_15_years_of_age = 0 where trim(world_nutrition_and_health_dap_2020.total_alcohol_consumption_per_capita_male_liters_of_pure_alcohol_projected_estimates_male_15_years_of_age)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set tuberculosis_death_rate_per_100000_people = 0 where trim(world_nutrition_and_health_dap_2020.tuberculosis_death_rate_per_100000_people)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set unemployment_female_of_female_labor_force = 0 where trim(world_nutrition_and_health_dap_2020.unemployment_female_of_female_labor_force)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set unemployment_male_of_male_labor_force = 0 where trim(world_nutrition_and_health_dap_2020.unemployment_male_of_male_labor_force)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set unemployment_total_of_total_labor_force = 0 where trim(world_nutrition_and_health_dap_2020.unemployment_total_of_total_labor_force)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set capital_health_expenditure_of_gdp = 0 where trim(world_nutrition_and_health_dap_2020.capital_health_expenditure_of_gdp)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set cause_of_death_by_communicable_diseases_and_maternal_prenatal_and_nutrition_conditions_of_total = 0 where trim(world_nutrition_and_health_dap_2020.cause_of_death_by_communicable_diseases_and_maternal_prenatal_and_nutrition_conditions_of_total)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set cause_of_death_by_injury_of_total = 0 where trim(world_nutrition_and_health_dap_2020.cause_of_death_by_injury_of_total)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set cause_of_death_by_noncommunicable_diseases_of_total = 0 where trim(world_nutrition_and_health_dap_2020.cause_of_death_by_noncommunicable_diseases_of_total)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set children_014_living_with_hiv = 0 where trim(world_nutrition_and_health_dap_2020.children_014_living_with_hiv)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set children_ages_014_newly_infected_with_hiv = 0 where trim(world_nutrition_and_health_dap_2020.children_ages_014_newly_infected_with_hiv)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set condom_use_population_ages_1524_female_of_females_ages_1524 = 0 where trim(world_nutrition_and_health_dap_2020.condom_use_population_ages_1524_female_of_females_ages_1524)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set condom_use_population_ages_1524_male_of_males_ages_1524 = 0 where trim(world_nutrition_and_health_dap_2020.condom_use_population_ages_1524_male_of_males_ages_1524)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set consumption_of_iodized_salt_of_households = 0 where trim(world_nutrition_and_health_dap_2020.consumption_of_iodized_salt_of_households)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set contraceptive_prevalence_any_methods_of_women_ages_1549 = 0 where trim(world_nutrition_and_health_dap_2020.contraceptive_prevalence_any_methods_of_women_ages_1549)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set contraceptive_prevalence_modern_methods_of_women_ages_1549 = 0 where trim(world_nutrition_and_health_dap_2020.contraceptive_prevalence_modern_methods_of_women_ages_1549)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set current_health_expenditure_of_gdp = 0 where trim(world_nutrition_and_health_dap_2020.current_health_expenditure_of_gdp)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set demand_for_family_planning_satisfied_by_any_methods_of_married_women_with_demand_for_family_planning = 0 where trim(world_nutrition_and_health_dap_2020.demand_for_family_planning_satisfied_by_any_methods_of_married_women_with_demand_for_family_planning)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set demand_for_family_planning_satisfied_by_modern_methods_of_married_women_with_demand_for_family_planning = 0 where trim(world_nutrition_and_health_dap_2020.demand_for_family_planning_satisfied_by_modern_methods_of_married_women_with_demand_for_family_planning)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set diabetes_prevalence_of_population_ages_20_to_79 = 0 where trim(world_nutrition_and_health_dap_2020.diabetes_prevalence_of_population_ages_20_to_79)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set exclusive_breastfeeding_of_children_under_6_months = 0 where trim(world_nutrition_and_health_dap_2020.exclusive_breastfeeding_of_children_under_6_months)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set external_health_expenditure_of_current_health_expenditure = 0 where trim(world_nutrition_and_health_dap_2020.external_health_expenditure_of_current_health_expenditure)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set external_health_expenditure_channeled_through_government_of_external_health_expenditure = 0 where trim(world_nutrition_and_health_dap_2020.external_health_expenditure_channeled_through_government_of_external_health_expenditure)= \'{patrn}\'")

engine.execute(f"Update world_nutrition_and_health_dap_2020 set external_health_expenditure_per_capita_ppp_current_international_ = 0 where trim(world_nutrition_and_health_dap_2020.external_health_expenditure_per_capita_ppp_current_international_)= \'{patrn}\'")

# %% [markdown]
# <h2> Creating new table to load filtered and selected columns :

# %%
# Create the engine and connect to the database
# engine = sqlalchemy.create_engine("postgresql+psycopg2://user:password@host:port/dbname")
try:
    engine = sqlalchemy.create_engine("postgresql+psycopg2://dap:dap@192.168.56.30:5432/postgres")
    dbconn = engine.connect()
except: 
    print("Error: Could not make connection to the Postgres database")
    print(e)

# Check for existing tables in the database
engine.table_names()
# Out:
# ['stack_overflow_survey_2020',
#  'edu_stats1',
#  'clean_stack_overflow_survey_2020',
#  'world_nutrition_and_health_dap_2020',
#  'world_nutrition_and_health_dap_2020_v2']

# %%
db_dataset_V2 = pd.read_sql("SELECT world_nutrition_and_health_dap_2020.country_name,world_nutrition_and_health_dap_2020.variable as year,world_nutrition_and_health_dap_2020.country_code,world_nutrition_and_health_dap_2020.literacy_rate_adult_female_of_females_ages_15_and_above,world_nutrition_and_health_dap_2020.literacy_rate_adult_male_of_males_ages_15_and_above,world_nutrition_and_health_dap_2020.literacy_rate_adult_total_of_people_ages_15_and_above,world_nutrition_and_health_dap_2020.literacy_rate_youth_male_of_males_ages_1524,world_nutrition_and_health_dap_2020.literacy_rate_youth_total_of_people_ages_1524,world_nutrition_and_health_dap_2020.number_of_deaths_ages_1014_years,world_nutrition_and_health_dap_2020.number_of_deaths_ages_1519_years,world_nutrition_and_health_dap_2020.number_of_deaths_ages_2024_years,world_nutrition_and_health_dap_2020.number_of_deaths_ages_59_years,world_nutrition_and_health_dap_2020.number_of_infant_deaths,world_nutrition_and_health_dap_2020.number_of_infant_deaths_female,world_nutrition_and_health_dap_2020.number_of_infant_deaths_male,world_nutrition_and_health_dap_2020.number_of_maternal_deaths,world_nutrition_and_health_dap_2020.number_of_neonatal_deaths,world_nutrition_and_health_dap_2020.number_of_stillbirths,world_nutrition_and_health_dap_2020.total_alcohol_consumption_per_capita_female_liters_of_pure_alcohol_projected_estimates_female_15_years_of_age,world_nutrition_and_health_dap_2020.total_alcohol_consumption_per_capita_male_liters_of_pure_alcohol_projected_estimates_male_15_years_of_age,world_nutrition_and_health_dap_2020.tuberculosis_death_rate_per_100000_people,world_nutrition_and_health_dap_2020.unemployment_female_of_female_labor_force,world_nutrition_and_health_dap_2020.unemployment_male_of_male_labor_force,world_nutrition_and_health_dap_2020.unemployment_total_of_total_labor_force,world_nutrition_and_health_dap_2020.capital_health_expenditure_of_gdp,world_nutrition_and_health_dap_2020.cause_of_death_by_communicable_diseases_and_maternal_prenatal_and_nutrition_conditions_of_total,world_nutrition_and_health_dap_2020.cause_of_death_by_injury_of_total,world_nutrition_and_health_dap_2020.cause_of_death_by_noncommunicable_diseases_of_total,world_nutrition_and_health_dap_2020.children_014_living_with_hiv,world_nutrition_and_health_dap_2020.children_ages_014_newly_infected_with_hiv,world_nutrition_and_health_dap_2020.condom_use_population_ages_1524_female_of_females_ages_1524,world_nutrition_and_health_dap_2020.condom_use_population_ages_1524_male_of_males_ages_1524,world_nutrition_and_health_dap_2020.consumption_of_iodized_salt_of_households,world_nutrition_and_health_dap_2020.contraceptive_prevalence_any_methods_of_women_ages_1549,world_nutrition_and_health_dap_2020.contraceptive_prevalence_modern_methods_of_women_ages_1549,world_nutrition_and_health_dap_2020.current_health_expenditure_of_gdp,world_nutrition_and_health_dap_2020.demand_for_family_planning_satisfied_by_any_methods_of_married_women_with_demand_for_family_planning,world_nutrition_and_health_dap_2020.demand_for_family_planning_satisfied_by_modern_methods_of_married_women_with_demand_for_family_planning,world_nutrition_and_health_dap_2020.diabetes_prevalence_of_population_ages_20_to_79,world_nutrition_and_health_dap_2020.exclusive_breastfeeding_of_children_under_6_months,world_nutrition_and_health_dap_2020.external_health_expenditure_of_current_health_expenditure,world_nutrition_and_health_dap_2020.external_health_expenditure_channeled_through_government_of_external_health_expenditure,world_nutrition_and_health_dap_2020.external_health_expenditure_per_capita_ppp_current_international_ FROM world_nutrition_and_health_dap_2020", dbconn)

# Set the table name
table = 'world_nutrition_and_health_dap_2020_v2'

# Write the dataframe to the database as a table
try:
    db_dataset_V2.to_sql(table, dbconn, if_exists = 'fail', index= False)
    #engine.execute("SELECT * FROM world_nutrition_and_health_dap_2020").fetchall()
except ValueError as e:
    print('Table already exists')
except Exception as exc:
    print(exc)
else:
    print(f'Table {table} was created with success.')
# Out:
# Table already exists

# %%
engine.execute("SELECT * FROM world_nutrition_and_health_dap_2020_v2")

# %%
dbconn.close()

# %% [markdown]
# <h3> loading new table into csv and dataframe

# %%
db_dataset_V2.to_csv(os.getcwd() + '/db_dataset_V2.csv')
db_dataset_V2
# Out:
#                                     country_name  year country_code  \
# 0                                    Afghanistan  2011          AFG
# 1                                    Afghanistan  2018          AFG
# 2                                        Albania  2008          ALB
# 3                                        Albania  2018          ALB
# 4                                        Albania  2011          ALB
# ...                                          ...   ...          ...
# 4139  East_Asia_&_Pacific_(IDA_&_IBRD_countries)  2020          TEA
# 4140                             North_Macedonia  2020          MKD
# 4141                               Faroe_Islands  2005          FRO
# 4142                               Faroe_Islands  2017          FRO
# 4143                    St._Martin_(French_part)  2015          MAF
#
#      literacy_rate_adult_female_of_females_ages_15_and_above  \
# 0                                                17.01783943
# ...

# %% [markdown]
# checking for countries :

# %%
# Create the engine and connect to the database
# engine = sqlalchemy.create_engine("postgresql+psycopg2://user:password@host:port/dbname")
try:
    engine = sqlalchemy.create_engine("postgresql+psycopg2://dap:dap@192.168.56.30:5432/postgres")
    dbconn = engine.connect()
except: 
    print("Error: Could not make connection to the Postgres database")
    print(e)

# Check for existing tables in the database
engine.table_names()
# Out:
# ['stack_overflow_survey_2020',
#  'edu_stats1',
#  'clean_stack_overflow_survey_2020',
#  'world_nutrition_and_health_dap_2020',
#  'world_nutrition_and_health_dap_2020_v2']

# %%
countries= "Afghanistan", "Albania", "Algeria", "Andorra", "Angola", "Antigua and Barbuda", "Argentina", "Armenia", "Australia", "Austria", "Azerbaijan", "Bahamas", "Bahrain", "Bangladesh", "Barbados", "Belarus", "Belgium", "Belize", "Benin", "Bhutan", "Bolivia", "Bosnia and Herzegovina", "Botswana", "Brazil", "Brunei Darussalam", "Bulgaria", "Burkina Faso", "Burundi", "Cambodia", "Cameroon", "Canada", "Cape Verde", "Chad", "Chile", "China", "Colombia", "Congo, Republic of the...", "Costa Rica", "Croatia", "Cuba", "Cyprus", "Czech Republic", "Democratic Republic of the Congo", "Denmark", "Djibouti", "Dominican Republic", "Ecuador", "Egypt", "El Salvador", "Eritrea", "Estonia", "Ethiopia", "Fiji", "Finland", "France", "Gabon", "Gambia", "Georgia", "Germany", "Ghana", "Greece", "Grenada", "Guatemala", "Guinea", "Guyana", "Haiti", "Honduras", "Hong Kong (S.A.R.)", "Hungary", "Iceland", "India", "Indonesia", "Iran", "Iraq", "Ireland", "Isle of Man", "Israel", "Italy", "Jamaica", "Japan", "Jordan", "Kazakhstan", "Kenya", "Kiribati", "Kosovo", "Kuwait", "Kyrgyzstan",  "Latvia", "Lebanon", "Lesotho", "Libyan Arab Jamahiriya", "Liechtenstein", "Lithuania", "Luxembourg", "Madagascar", "Malawi", "Malaysia", "Maldives", "Mali", "Malta", "Marshall Islands", "Mauritania", "Mauritius", "Mexico", "Micronesia, Federated States of...", "Monaco", "Mongolia", "Montenegro", "Morocco", "Mozambique", "Myanmar", "Namibia", "Nauru", "Nepal", "Netherlands", "New Zealand", "Nicaragua", "Niger", "Nigeria", "Nomadic", "North Korea", "Norway", "Oman", "Pakistan", "Panama", "Papua New Guinea", "Paraguay", "Peru", "Philippines", "Poland", "Portugal", "Qatar", "Republic of Korea", "Republic of Moldova", "Romania", "Russian Federation", "Rwanda", "Saint Lucia", "Saint Vincent and the Grenadines", "San Marino", "Saudi Arabia", "Senegal", "Serbia", "Sierra Leone", "Singapore", "Slovakia", "Slovenia", "Solomon Islands", "Somalia", "South Africa", "South Korea", "Spain", "Sri Lanka", "Sudan", "Swaziland", "Sweden", "Switzerland", "Syrian Arab Republic", "Taiwan", "Tajikistan", "Thailand", "The former Yugoslav Republic of Macedonia", "Timor-Leste", "Togo", "Trinidad and Tobago", "Tunisia", "Turkey", "Turkmenistan", "Uganda", "Ukraine", "United Arab Emirates", "United Kingdom", "United Republic of Tanzania", "United States", "Uruguay", "Uzbekistan", "Venezuela, Bolivarian Republic of...", "Viet Nam", "Yemen", "Zambia", "Zimbabwe"

db_dataset_v3 = pd.read_sql(f"SELECT * from world_nutrition_and_health_dap_2020_V2 where country_name in {countries}", dbconn)

# %%
dbconn.close()

# %%
db_dataset_v3
# Out:
#      country_name  year country_code  \
# 0     Afghanistan  2011          AFG
# 1     Afghanistan  2018          AFG
# 2         Albania  2008          ALB
# 3         Albania  2018          ALB
# 4         Albania  2011          ALB
# ...           ...   ...          ...
# 2091      Iceland  2020          ISL
# 2092      Croatia  2020          HRV
# 2093     Botswana  2020          BWA
# 2094        Kenya  2020          KEN
# 2095     Cameroon  2020          CMR
#
#      literacy_rate_adult_female_of_females_ages_15_and_above  \
# 0                                                17.01783943
# 1                                                29.80521011
# 2                                                94.68180847
# 3                                                97.76112366
# 4                                                95.69148254
# ...                                                      ...
# 2091                                                       0
# ...

# %%
# Create the engine and connect to the database
# engine = sqlalchemy.create_engine("postgresql+psycopg2://user:password@host:port/dbname")
try:
    engine = sqlalchemy.create_engine("postgresql+psycopg2://dap:dap@192.168.56.30:5432/postgres")
    dbconn = engine.connect()
except: 
    print("Error: Could not make connection to the Postgres database")
    print(e)

# Check for existing tables in the database
engine.table_names()
# Out:
# ['stack_overflow_survey_2020',
#  'edu_stats1',
#  'clean_stack_overflow_survey_2020',
#  'world_nutrition_and_health_dap_2020',
#  'world_nutrition_and_health_dap_2020_v2']

# %%
# Set the table name
table = 'world_nutrition_and_health_dap_2020_v3'

# Write the dataframe to the database as a table
try:
    db_dataset_v3.to_sql(table, dbconn, if_exists = 'fail', index= False)
    #engine.execute("SELECT * FROM world_nutrition_and_health_dap_2020").fetchall()
except ValueError as e:
    print('Table already exists')
except Exception as exc:
    print(exc)
else:
    print(f'Table {table} was created with success.')
finally:
    dbconn.close()
# Out:
# Table world_nutrition_and_health_dap_2020_v3 was created with success.

# %%
db_dataset_v3.to_csv(os.getcwd() + '/db_dataset_v3.csv', index=False)
db_dataset_v3
# Out:
#      country_name  year country_code  \
# 0     Afghanistan  2011          AFG
# 1     Afghanistan  2018          AFG
# 2         Albania  2008          ALB
# 3         Albania  2018          ALB
# 4         Albania  2011          ALB
# ...           ...   ...          ...
# 2091      Iceland  2020          ISL
# 2092      Croatia  2020          HRV
# 2093     Botswana  2020          BWA
# 2094        Kenya  2020          KEN
# 2095     Cameroon  2020          CMR
#
#      literacy_rate_adult_female_of_females_ages_15_and_above  \
# 0                                                17.01783943
# 1                                                29.80521011
# 2                                                94.68180847
# 3                                                97.76112366
# 4                                                95.69148254
# ...                                                      ...
# 2091                                                       0
# ...

# %% [markdown]
# <h2> Analysing columns :    </h2>
#
#
#
#
#
#     literacy_rate_adult_female_of_females_ages_15_and_above
#     literacy_rate_adult_male_of_males_ages_15_and_above
#     literacy_rate_adult_total_of_people_ages_15_and_above

# %%
import seaborn as sns
import matplotlib.pyplot as plt


db_dataset_v3['literacy_rate_adult_female_of_females_ages_15_and_above']=db_dataset_v3['literacy_rate_adult_female_of_females_ages_15_and_above'].astype('float64')
db_dataset_v3['literacy_rate_adult_male_of_males_ages_15_and_above']=db_dataset_v3['literacy_rate_adult_male_of_males_ages_15_and_above'].astype('float64')
db_dataset_v3['literacy_rate_adult_total_of_people_ages_15_and_above']=db_dataset_v3['literacy_rate_adult_total_of_people_ages_15_and_above'].astype('float64')

plt.figure(figsize=(14,8))
ax = plt.gca()

db_dataset_v3.plot(kind='line',x='country_name',y='literacy_rate_adult_female_of_females_ages_15_and_above',ax=ax)

plt.legend(bbox_to_anchor=(1.45, 1))
#db_dataset_v3.plot(kind='line',x='year',y='literacy_rate_adult_male_of_males_ages_15_and_above', color='red', ax=ax)

plt.show()

# %%
db_dataset_v3['literacy_rate_adult_female_of_females_ages_15_and_above']=db_dataset_v3['literacy_rate_adult_female_of_females_ages_15_and_above'].astype('float64')
db_dataset_v3['literacy_rate_adult_male_of_males_ages_15_and_above']=db_dataset_v3['literacy_rate_adult_male_of_males_ages_15_and_above'].astype('float64')
db_dataset_v3['literacy_rate_adult_total_of_people_ages_15_and_above']=db_dataset_v3['literacy_rate_adult_total_of_people_ages_15_and_above'].astype('float64')


plt.figure(figsize=(14,8))
ax = plt.gca()

db_dataset_v3.plot(kind='bar',x='country_name',y='literacy_rate_adult_male_of_males_ages_15_and_above',color='green',ax=ax)

plt.legend(bbox_to_anchor=(1.45, 1))
#db_dataset_v3.plot(kind='line',x='year',y='literacy_rate_adult_male_of_males_ages_15_and_above', color='red', ax=ax)


plt.show()

# %%
db_dataset_v3['literacy_rate_adult_female_of_females_ages_15_and_above']=db_dataset_v3['literacy_rate_adult_female_of_females_ages_15_and_above'].astype('float64')
db_dataset_v3['literacy_rate_adult_male_of_males_ages_15_and_above']=db_dataset_v3['literacy_rate_adult_male_of_males_ages_15_and_above'].astype('float64')
db_dataset_v3['literacy_rate_adult_total_of_people_ages_15_and_above']=db_dataset_v3['literacy_rate_adult_total_of_people_ages_15_and_above'].astype('float64')


plt.figure(figsize=(14,8))
ax = plt.gca()

db_dataset_v3.plot(kind='line',x='country_name',y='literacy_rate_adult_total_of_people_ages_15_and_above',color='red',ax=ax)
#db_dataset_v3.plot(kind='line',x='year',y='literacy_rate_adult_male_of_males_ages_15_and_above', color='red', ax=ax)

plt.legend(bbox_to_anchor=(1.45, 1))

plt.show()

# %%
#### Literacy rate of female all over world !!!

db_dataset_v3['literacy_rate_adult_female_of_females_ages_15_and_above'].hist(bins=30);

# %%
#### Literacy rate of male all over world 

db_dataset_v3['literacy_rate_adult_male_of_males_ages_15_and_above'].hist(bins=30);

# %%
#### Literacy rate of male all over world 

db_dataset_v3['literacy_rate_adult_total_of_people_ages_15_and_above'].hist(bins=30);

# %% [markdown]
# <h2> Analyzing Columns :</h2>
#
#
#     number_of_deaths_ages_1014_years
#     number_of_deaths_ages_1519_years
#     number_of_deaths_ages_2024_years
#     number_of_deaths_ages_59_years
#     number_of_infant_deaths
#     number_of_infant_deaths_female
#     number_of_infant_deaths_male
#     number_of_maternal_deaths
#     number_of_neonatal_deaths
#     number_of_stillbirths

# %%
db_dataset_v3['number_of_deaths_ages_1014_years']=db_dataset_v3['number_of_deaths_ages_1014_years'].astype('float64')
db_dataset_v3['number_of_deaths_ages_1519_years']=db_dataset_v3['number_of_deaths_ages_1519_years'].astype('float64')
db_dataset_v3['number_of_deaths_ages_2024_years']=db_dataset_v3['number_of_deaths_ages_2024_years'].astype('float64')
db_dataset_v3['number_of_deaths_ages_59_years']=db_dataset_v3['number_of_deaths_ages_59_years'].astype('float64')
db_dataset_v3['number_of_infant_deaths']=db_dataset_v3['number_of_infant_deaths'].astype('float64')
db_dataset_v3['number_of_infant_deaths_female']=db_dataset_v3['number_of_infant_deaths_female'].astype('float64')
db_dataset_v3['number_of_infant_deaths_male']=db_dataset_v3['number_of_infant_deaths_male'].astype('float64')
db_dataset_v3['number_of_maternal_deaths']=db_dataset_v3['number_of_maternal_deaths'].astype('float64')
db_dataset_v3['number_of_neonatal_deaths']=db_dataset_v3['number_of_neonatal_deaths'].astype('float64')
db_dataset_v3['number_of_stillbirths']=db_dataset_v3['number_of_stillbirths'].astype('float64')


plt.figure(figsize = (14,10))
ax = plt.gca()

db_dataset_v3.plot(kind='bar',x='year',y='number_of_infant_deaths_female',ax=ax)
db_dataset_v3.plot(kind='line',x='year',y='number_of_infant_deaths_female', color='red', ax=ax)
db_dataset_v3.plot(kind='line',x='year',y='number_of_infant_deaths', color='green', ax=ax)

plt.legend(bbox_to_anchor=(1.3, 1))

plt.show()

# %% [markdown]
# <h1> Merging Tables :

# %%
#Marcelo's Table 
clean_survey_results_2020_v1 = pd.read_csv(os.getcwd() + '/clean_survey_results_2020.csv')

#Anjuli's Table
db_dataset_v3

#Dawn's table 
clean_edu_stats_v1 = pd.read_csv(os.getcwd() + '/clean_edu_stats.csv')

# %%
clean_edu_stats_v1.rename(columns={'Country_Name': 'country_name_dawn'},
                          inplace=True)

# %%
#cleaning Dawn's data 

# clean_edu_stats_v1.head()
clean_edu_stats_v1.columns = clean_edu_stats_v1.columns.str.replace(r'\[|\]', '')
clean_edu_stats_v1.columns = clean_edu_stats_v1.columns.str.replace(r'\%', '')
clean_edu_stats_v1.columns = clean_edu_stats_v1.columns.str.replace(' ', '')
clean_edu_stats_v1.columns = clean_edu_stats_v1.columns.str.replace('\(|\)', '')
clean_edu_stats_v1.columns = clean_edu_stats_v1.columns.str.replace(r'\$', '')
clean_edu_stats_v1.columns = clean_edu_stats_v1.columns.str.replace(r'\-', '')
clean_edu_stats_v1.columns = clean_edu_stats_v1.columns.str.replace(r'\+', '')
clean_edu_stats_v1.columns = clean_edu_stats_v1.columns.str.replace(r'\__', '_')
clean_edu_stats_v1.columns = clean_edu_stats_v1.columns.str.replace(r'\,', '_')

# %%
clean_edu_stats_v1.drop(columns=['Governmentexpenditureoneducationnotspecifiedbylevel_PPPmillions',
                                 'Governmentexpenditureoneducationnotspecifiedbylevel_USmillions',
                                 'Participationrateofyouthandadultsinformalandnonformaleducationandtrainingintheprevious12months_adjustedgenderparityindexGPIA',
                                 'Participationrateofyouthandadultsinformalandnonformaleducationandtrainingintheprevious12months_bothsexes',
                                 'Participationrateofyouthandadultsinformalandnonformaleducationandtrainingintheprevious12months_female',
                                 'Participationrateofyouthandadultsinformalandnonformaleducationandtrainingintheprevious12months_male'],
                        axis=1,
                        inplace=True)

# %%
clean_edu_stats_v1.columns = clean_edu_stats_v1.columns.str.lower()

# %%
# clean_edu_stats_v1.columns.to_list()

# %%
#clean_survey_results_2020_v1
clean_edu_stats_v1
# Out:
#      country_name_dawn country_code  year  \
# 0          Afghanistan          AFG  2005
# 1          Afghanistan          AFG  2006
# 2          Afghanistan          AFG  2007
# 3          Afghanistan          AFG  2008
# 4          Afghanistan          AFG  2009
# ...                ...          ...   ...
# 3277          Zimbabwe          ZWE  2013
# 3278          Zimbabwe          ZWE  2014
# 3279          Zimbabwe          ZWE  2015
# 3280          Zimbabwe          ZWE  2017
# 3281          Zimbabwe          ZWE  2018
#
#       expenditureoneducationasoftotalgovernmentexpenditure  \
# 0                                                  0.00000
# 1                                                  0.00000
# 2                                                  0.00000
# 3                                                  0.00000
# 4                                                  0.00000
# ...                                                    ...
# ...

# %%
# Create the engine and connect to the database
# engine = sqlalchemy.create_engine("postgresql+psycopg2://user:password@host:port/dbname")
try:
    engine = sqlalchemy.create_engine("postgresql+psycopg2://dap:dap@192.168.56.30:5432/postgres")
    dbconn = engine.connect()
except: 
    print("Error: Could not make connection to the Postgres database")
    print(e)

# Check for existing tables in the database
engine.table_names()
# Out:
# ['stack_overflow_survey_2020',
#  'edu_stats1',
#  'clean_stack_overflow_survey_2020',
#  'world_nutrition_and_health_dap_2020',
#  'world_nutrition_and_health_dap_2020_v2',
#  'clean_edu_stats_v1',
#  'world_nutrition_and_health_dap_2020_v3',
#  'clean_survey_results_2020_v1']

# %%
# engine.execute("DROP TABLE clean_edu_stats_v1")

# %%
##creating new table for Marcelo --- 

# Set the table name
table = 'clean_survey_results_2020_v1'

# Write the dataframe to the database as a table
try:
    clean_survey_results_2020_v1.to_sql(table, dbconn, if_exists = 'fail', index= False)
    #engine.execute("SELECT * FROM world_nutrition_and_health_dap_2020").fetchall()
except ValueError as e:
    print('Table already exists')
except Exception as exc:
    print(exc)
else:
    print(f'Table {table} was created with success.')
# Out:
# Table already exists

# %%
##creating new table for Dawn --- 

# Set the table name
table = 'clean_edu_stats_v1'

# Write the dataframe to the database as a table
try:
    clean_edu_stats_v1.to_sql(table, dbconn, if_exists = 'fail', index= False)
    #engine.execute("SELECT * FROM world_nutrition_and_health_dap_2020").fetchall()
except ValueError as e:
    print('Table already exists')
except Exception as exc:
    print(exc)
else:
    print(f'Table {table} was created with success.')
# Out:
# Table clean_edu_stats_v1 was created with success.

# %%
#Marcelo table name - clean_survey_results_2020_v1
#anjuli table name - world_nutrition_and_health_dap_2020_v3

test = engine.execute("SELECT * FROM world_nutrition_and_health_dap_2020_v3 left join clean_edu_stats_v1 on trim(clean_edu_stats_v1.country_name_dawn)=trim(world_nutrition_and_health_dap_2020_v3.country_name) and clean_edu_stats_v1.year=world_nutrition_and_health_dap_2020_v3.year").fetchall()

# %%
merged_v1 = pd.read_sql("SELECT * FROM world_nutrition_and_health_dap_2020_v3 left join clean_edu_stats_v1 on trim(clean_edu_stats_v1.country_name_dawn)=trim(world_nutrition_and_health_dap_2020_v3.country_name) and clean_edu_stats_v1.year=world_nutrition_and_health_dap_2020_v3.year", dbconn)

# %%
dbconn.close()

# %%
merged_v1.to_csv(os.getcwd() + '/merged_v1.csv')
merged_v1
# Out:
#      country_name  year country_code  \
# 0     Afghanistan  2005          AFG
# 1     Afghanistan  2006          AFG
# 2     Afghanistan  2007          AFG
# 3     Afghanistan  2008          AFG
# 4     Afghanistan  2009          AFG
# ...           ...   ...          ...
# 2091     Zimbabwe  2016          ZWE
# 2092     Zimbabwe  2017          ZWE
# 2093     Zimbabwe  2018          ZWE
# 2094     Zimbabwe  2019          ZWE
# 2095     Zimbabwe  2020          ZWE
#
#      literacy_rate_adult_female_of_females_ages_15_and_above  \
# 0                                                          0
# 1                                                          0
# 2                                                          0
# 3                                                          0
# 4                                                          0
# ...                                                      ...
# 2091                                                       0
# ...

# %%
merged_v1.dtypes
# Out:
# country_name                                                        object
# year                                                                 int64
# country_code                                                        object
# literacy_rate_adult_female_of_females_ages_15_and_above             object
# literacy_rate_adult_male_of_males_ages_15_and_above                 object
#                                                                     ...
# percentageofgraduatesfromtertiaryeducationgraduatingfromnatural    float64
# percentageofgraduatesfromtertiaryeducationgraduatingfromservice    float64
# percentageofgraduatesfromtertiaryeducationgraduatingfromsocials    float64
# percentageofgraduatesfromtertiaryeducationgraduatingfromprogram    float64
# percentageoftotalaidtoeducationallocatedtoleastdevelopedcountri    float64
# Length: 89, dtype: object

# %%
### Changing datatypes 

merged_v1['number_of_deaths_ages_1014_years']=merged_v1['number_of_deaths_ages_1014_years'].astype('float64')
merged_v1['number_of_deaths_ages_1519_years']=merged_v1['number_of_deaths_ages_1519_years'].astype('float64')
merged_v1['number_of_deaths_ages_2024_years']=merged_v1['number_of_deaths_ages_2024_years'].astype('float64')
merged_v1['number_of_deaths_ages_59_years']=merged_v1['number_of_deaths_ages_59_years'].astype('float64')
merged_v1['number_of_infant_deaths']=merged_v1['number_of_infant_deaths'].astype('float64')
merged_v1['number_of_infant_deaths_female']=merged_v1['number_of_infant_deaths_female'].astype('float64')
merged_v1['number_of_infant_deaths_male']=merged_v1['number_of_infant_deaths_male'].astype('float64')
merged_v1['number_of_maternal_deaths']=merged_v1['number_of_maternal_deaths'].astype('float64')
merged_v1['number_of_neonatal_deaths']=merged_v1['number_of_neonatal_deaths'].astype('float64')
merged_v1['number_of_stillbirths']=merged_v1['number_of_stillbirths'].astype('float64')
merged_v1['literacy_rate_adult_female_of_females_ages_15_and_above']=merged_v1['literacy_rate_adult_female_of_females_ages_15_and_above'].astype('float64')
merged_v1['literacy_rate_adult_male_of_males_ages_15_and_above']=merged_v1['literacy_rate_adult_male_of_males_ages_15_and_above'].astype('float64')
merged_v1['literacy_rate_adult_total_of_people_ages_15_and_above']=merged_v1['literacy_rate_adult_total_of_people_ages_15_and_above'].astype('float64')
merged_v1['unemployment_total_of_total_labor_force']=merged_v1['unemployment_total_of_total_labor_force'].astype('float64')
merged_v1['unemployment_female_of_female_labor_force']=merged_v1['unemployment_female_of_female_labor_force'].astype('float64')
merged_v1['unemployment_male_of_male_labor_force']=merged_v1['unemployment_male_of_male_labor_force'].astype('float64')

# %% [markdown]
# <h2> Analyse on joined data:

# %%
# merged_v1['country_name1'] = merged_v1['country_name']
merged_v1.drop(columns='country_name_dawn', axis=1, inplace=True)
agga_data_v1 = merged_v1.groupby('country_name').agg('sum')
agga_data_v1.to_csv('agga_data_v1.csv')
agga_data_v1.reset_index(inplace=True)

# %%
### ranking countries on basis of Expenditureoneducationasoftotalgovernmentexpenditure 
#agga_data_v1['country_name1'] = agga_data_v1['country_name']
agga_data_v1['rnk'] = agga_data_v1['expenditureoneducationasoftotalgovernmentexpenditure'].rank(method='max')

# %%
agga_data_v1
# Out:
#     country_name   year  \
# 0    Afghanistan  32200
# 1        Albania  32200
# 2        Algeria  32200
# 3        Andorra  32200
# 4         Angola  32200
# ..           ...    ...
# 126      Ukraine  32200
# 127      Uruguay  32200
# 128   Uzbekistan  32200
# 129       Zambia  32200
# 130     Zimbabwe  32200
#
#      literacy_rate_adult_female_of_females_ages_15_and_above  \
# 0                                                  46.823050
# 1                                                 384.270485
# 2                                                 206.790508
# 3                                                   0.000000
# 4                                                  53.407211
# ..                                                       ...
# 126                                                99.958199
# 127                                              1282.229164
# 128                                               499.911911
# ...

# %%
agga_data_v1_top15 = agga_data_v1[agga_data_v1['rnk']<15]
agga_data_v1_lest15 = agga_data_v1[agga_data_v1['rnk']>115]

# %% [markdown]
# <h2> Graph - top 15 countries who invested most in education and health care  </h2>
#
# line 1 - Unemplyment trend in total
#
# line 2 - unemplyment trend in female
#
# line 3 - unemplyment trend in male

# %%
agga_data_v1_top15
# Out:
#       country_name   year  \
# 18         Bolivia  32200
# 28           China  32200
# 31            Cuba  32200
# 36         Eritrea  32200
# 46          Greece  32200
# 57            Iraq  32200
# 66        Kiribati  32200
# 67          Kosovo  32200
# 72   Liechtenstein  32200
# 86      Montenegro  32200
# 91           Nauru  32200
# 96         Nigeria  32200
# 113        Somalia  32200
# 123         Turkey  32200
#
#      literacy_rate_adult_female_of_females_ages_15_and_above  \
# 18                                                528.175476
# 28                                                187.870560
# 31                                                 99.799881
# 36                                                123.747261
# 46                                                468.321701
# 57                                                363.700005
# 66                                                  0.000000
# 67                                                  0.000000
# ...

# %%
plt.style.use('fivethirtyeight')
fontsize = 18
labelpad = 10

### data for top 15 countries - agga_data_v1_top15 

# Create the figure and the axes
fig, ax = plt.subplots(figsize=(16,12))

ax.set_xlabel("Countries", fontsize=fontsize, labelpad=labelpad)
ax.set_ylabel("Unemployment Percentage ", fontsize=fontsize, labelpad=labelpad)
ax.set_title("Unemployment rate for countries with highest expenditure in Education and health", fontsize=fontsize+2)

agga_data_v1_top15.plot(kind='line', x='country_name',y='unemployment_total_of_total_labor_force',ax=ax)
agga_data_v1_top15.plot(kind='line',x='country_name',y='unemployment_female_of_female_labor_force', color='red', ax=ax)
agga_data_v1_top15.plot(kind='line',x='country_name',y='unemployment_male_of_male_labor_force', color='green', ax=ax)


plt.show()

# %% [markdown]
# <h2> Graph - countries and death rate  </h2>
#
# line 1 - number_of_infant_deaths
#
# line 2 - number_of_deaths_ages_59_years
#
# line 3 - number_of_maternal_deaths
#
# line 4 - number_of_deaths_ages_2024_years
#
# line 5 - number_of_deaths_ages_1519_years
#
# line 6 - number_of_deaths_ages_1014_years

# %%
plt.style.use('fivethirtyeight')
fontsize = 18
labelpad = 10

### data for top 15 countries - agga_data_v1_top15 

# Create the figure and the axes
fig, ax = plt.subplots(figsize=(16,12))



ax.set_xlabel("Countries", fontsize=fontsize, labelpad=labelpad)
ax.set_ylabel("Death Count ", fontsize=fontsize, labelpad=labelpad)
ax.set_title("Death Count comparision for top least 15 countries ", fontsize=fontsize+2)

# Legend
#plt.legend(bbox_to_anchor=(1.35, 1), fontsize=12, title='Percentage', title_fontsize=12)

agga_data_v1_lest15.plot(kind='line', x='country_name',y='number_of_infant_deaths',ax=ax)
agga_data_v1_lest15.plot(kind='line',x='country_name',y='number_of_deaths_ages_59_years', color='red', ax=ax)
agga_data_v1_lest15.plot(kind='line',x='country_name',y='number_of_maternal_deaths', color='green', ax=ax)
agga_data_v1_lest15.plot(kind='line', x='country_name',y='number_of_deaths_ages_2024_years',color ='brown',ax=ax)
agga_data_v1_lest15.plot(kind='line',x='country_name',y='number_of_deaths_ages_1519_years', color='pink', ax=ax)
agga_data_v1_lest15.plot(kind='line',x='country_name',y='number_of_deaths_ages_1014_years', color='yellow', ax=ax)


plt.show()



# Legend
#plt.legend(bbox_to_anchor=(1.35, 1), fontsize=12, title_fontsize=12)

# %% [markdown]
# <h2> Analysing countries unemplyment across countries

# %%
# Create the figure and the axes
fig, ax = plt.subplots(figsize=(30,20))

sns.barplot(x='country_name', y='unemployment_total_of_total_labor_force', data=agga_data_v1, palette='colorblind')

# Aesthetics
# For labels:
# https://matplotlib.org/api/axes_api.html#appearance
ax.set_xlabel("Country ", fontsize=fontsize, labelpad=labelpad)
ax.set_ylabel("Count of unemployment", fontsize=fontsize, labelpad=labelpad)
ax.set_title("Total Count of unemployment", fontsize=fontsize+2)

# For tick parameters:
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.axes.Axes.tick_params.html
ax.tick_params(axis="x", labelsize=14)
ax.tick_params(axis="y", labelsize=13)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=12, rotation=90)
plt.show()
